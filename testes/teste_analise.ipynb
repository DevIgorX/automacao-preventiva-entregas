# %%
import pandas as pd

# %%
with open("tab_detalhe_modal (7)_Dados completos_data (2).csv", "r", encoding="latin-1") as f:
    print(f.readline())
# Out:
# "CD_Resp	cidade_cliente	transportador	PEDIDO 1P/FULL"

# %%
df_tab = pd.read_csv(
    "tab_detalhe_modal (7)_Dados completos_data (2).csv",
    sep="\t",
    quoting=3,        # Desabilita tratamento de aspas
    engine="python",
    encoding="latin-1"
)

# %%
df_tab.head(5)
# Out:
#   "CD_Resp cidade_cliente transportador PEDIDO 1P/FULL"
# 0    "1100        GOIANIA     PORTA APO     1115971792"
# 1    "1100        GOIANIA     PORTA APO     1116115099"
# 2    "1100        GOIANIA     PORTA APO     1116051634"
# 3    "1100        GOIANIA     PORTA APO     1116111441"
# 4    "1100        GOIANIA     PORTA APO     1116116815"

# %%
df_tab.to_csv("saida_tab.csv", sep="\t", index=False, encoding="latin-1")

# %%
df_tab.columns
# Out:
# Index(['"CD_Resp', 'cidade_cliente', 'transportador', 'PEDIDO 1P/FULL"'], dtype='object')

# %%
df_tab = df_tab.applymap(lambda x: x.strip('"') if isinstance(x, str) else x)
# Out:
# C:\Users\tauam.pinheiro\AppData\Local\Temp\ipykernel_10860\2208148980.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_tab = df_tab.applymap(lambda x: x.strip('"') if isinstance(x, str) else x)

# %%
df_tab.columns
# Out:
# Index(['"CD_Resp', 'cidade_cliente', 'transportador', 'PEDIDO 1P/FULL"'], dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_tab[['PEDIDO 1P/FULL ']]
#
# File c:\Users\tauam.pinheiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\tauam.pinheiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\tauam.pinheiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['PEDIDO 1P/FULL '], dtype='object')] are in the [columns]"

# %%
import os

# %%
preventiva = pd.read_csv("cd-etapa (3)_Dados completos_data - 2025-10-17T075817.370 (2).csv", sep='\t', encoding='latin-1')

# %%
relatorio_preventiva = pd.read_excel('Relatorio_DOMICILIO_2025-10-31 (2).xlsx')

# %%
mobile_relatorio = pd.read_excel('20251018091706-43794990000190-entregas.xls')

# %%
mobile_relatorio.head(5)
# Out:
#      Pedido Cliente        Pedido                                  UUID  \
# 0  1474270272545078  1.099514e+09  d88b235e-7bac-4d29-a580-dc1000708486
# 1  1474450186521141  1.099603e+09  a3b6ef87-50ad-48a2-8640-4593405fe389
# 2        1099617993  1.099618e+09  c6344b33-682c-4d5e-8f94-8cbd3724c55a
# 3        1099626099  1.099626e+09  b3932f98-46a5-4ee4-bf34-d6a84f682118
# 4  1474370272598717  1.099629e+09  54d54f52-e4de-4140-aa4e-731b8da5c16d
#
#       Romaneio                   Transportador  Nota Fiscal  Numero de Série  \
# 0  114001715.0  PORTA A PORTA TRANSPORTES LTDA       102962                7
# 1  114001715.0  PORTA A PORTA TRANSPORTES LTDA       103335                7
# 2  114001715.0  PORTA A PORTA TRANSPORTES LTDA       103333                7
# 3  114001715.0  PORTA A PORTA TRANSPORTES LTDA       103334                7
# 4  114001715.0  PORTA A PORTA TRANSPORTES LTDA       103336                7
#
#   Data Importação Pedido Data de Captura Data de Processamento  \
# 0         01/10/25 06:45  01/10/25 15:12        01/10/25 15:12
# 1         01/10/25 06:45  01/10/25 15:13        01/10/25 15:13
# 2         01/10/25 06:45  01/10/25 17:03        01/10/25 17:03
# 3         01/10/25 06:45  01/10/25 15:13        01/10/25 15:13
# 4         01/10/25 06:45  01/10/25 15:10        01/10/25 15:10
#
#                            Entregador                           Tipo
# 0  MARCELO SILVA DE CARVALHO(GOIANIA)  Entrega Realizada Normalmente
# 1  MARCELO SILVA DE CARVALHO(GOIANIA)  Entrega Realizada Normalmente
# 2  MARCELO SILVA DE CARVALHO(GOIANIA)  Entrega Realizada Normalmente
# 3  MARCELO SILVA DE CARVALHO(GOIANIA)  Entrega Realizada Normalmente
# 4  MARCELO SILVA DE CARVALHO(GOIANIA)  Entrega Realizada Normalmente

# %%
mobile_relatorio.Tipo.unique()
# Out:
# array(['Entrega Realizada Normalmente', 'Mercadoria devolvida ao CD',
#        'Entregue na loja', 'Entregue na Base do transportador',
#        'Troca de transportadora', 'Entrega Programada',
#        'Pedido cancelado pelo cliente',
#        'Endereço do Cliente Destino não Localizado', 'Em rota de entrega',
#        '1a Tentativa Cliente Ausente', 'Saiu para Entrega',
#        'A caminho da loja', 'Em processo de devolução CD'], dtype=object)

# %%
mobile_relatorio = mobile_relatorio[mobile_relatorio['Tipo'] == 'Entrega Realizada Normalmente']

# %%
mobile_relatorio.Tipo.unique()
# Out:
# array(['Entrega Realizada Normalmente'], dtype=object)

# %%
quantidade_entregues = len(mobile_relatorio)

# %%
quantidade_entregues
# Out:
# 3353

# %% [markdown]
# output_filename = os.path.join(caminho_dados, "Resultado_Monitoramento.xlsx")
# print(f"Gerando o arquivo de resultado: {output_filename}", file=sys.stderr)
#
# with pd.ExcelWriter(output_filename, engine='openpyxl') as writer:
#     df_pendentes.to_excel(writer, sheet_name="Pendentes", index=False)
#     df_finalizados.to_excel(writer, sheet_name="Finalizados", index=False)
#     df_preventiva.to_excel(writer, sheet_name="Preventiva", index=False)

# %%
caminho = os.getcwd()

# %%
caminho
# Out:
# 'c:\\Users\\pc\\Desktop\\Nova pasta\\Desktop\\Arquivos Domicilio\\preventiva-mobile\\testes'

# %%
output_filename = os.path.join(caminho, "Resultado.xlsx")

# %%
preventiva.head(5)
# Out:
#    CD_Resp transportador (grupo)          Cidade Cliente  pedido_gemco
# 0     1100             DOMICILIO  SANTA BARBARA DE GOIAS    1101636148
# 1     1100             DOMICILIO                 GOIANIA    1096258498
# 2     1100             DOMICILIO                 GOIANIA    1103381975
# 3     1100             DOMICILIO                 GOIANIA    1103380688
# 4     1100             DOMICILIO    APARECIDA DE GOIANIA    1103278675

# %%
filtrado = preventiva.query(" `Cidade Cliente` != 'ITUMBIARA' ")

# %%
filtrado
# Out:
#      CD_Resp transportador (grupo)          Cidade Cliente  pedido_gemco
# 0       1100             DOMICILIO  SANTA BARBARA DE GOIAS    1101636148
# 1       1100             DOMICILIO                 GOIANIA    1096258498
# 2       1100             DOMICILIO                 GOIANIA    1103381975
# 3       1100             DOMICILIO                 GOIANIA    1103380688
# 4       1100             DOMICILIO    APARECIDA DE GOIANIA    1103278675
# ..       ...                   ...                     ...           ...
# 136     1100             DOMICILIO                ANAPOLIS    1103384339
# 137     1100             DOMICILIO                 GOIANIA    1103389496
# 138     1100             DOMICILIO                 GOIANIA    1103393818
# 139     1100             DOMICILIO                 GOIANIA    1103571413
# 140     1100             DOMICILIO                ANAPOLIS    1103521520
#
# [139 rows x 4 columns]

# %%
preventiva_df = pd.read_excel('Relatorio_DOMICILIO_2025-10-31 (2).xlsx')

# %%
preventiva_df.columns
# Out:
# Index(['transportador (grupo)', 'Cidade Cliente', 'PEDIDO 1P/FULL'], dtype='object')

# %%
preventiva_df[['PEDIDO 1P/FULL']]
# Out:
#      PEDIDO 1P/FULL
# 0        1106390363
# 1        1106339530
# 2        1106463782
# 3        1106473559
# 4        1106378135
# ..              ...
# 128      1106444652
# 129      1106272027
# 130      1106276180
# 131      1106287686
# 132      1106115549
#
# [133 rows x 1 columns]
