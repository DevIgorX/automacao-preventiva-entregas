# %%
import pandas as pd

# %%
df_resultado_relatorio = pd.read_excel('Resultado_Monitoramento.xlsx')

# %%
df_resultado_relatorio.head(3)
# Out:
#    CD_Resp transportador (grupo) Cidade Cliente  pedido_gemco  \
# 0     1100             DOMICILIO       ANAPOLIS    1098196304
# 1     1100             DOMICILIO        GOIANIA    1098193478
# 2     1100             DOMICILIO        GOIANIA    1098271106
#
#      Pedido Cliente      Pedido                                  UUID  \
# 0  1472470271835413  1098196304  43070eb0-1aef-421b-8563-9ac33600a477
# 1  1472470271833265  1098193478  9870e223-5d72-4f3c-aaed-e5e9cba6853f
# 2        1098271106  1098271106  25b0efe4-17c4-4d50-bedb-fe856651449e
#
#     Romaneio                   Transportador  Nota Fiscal  Numero de Série  \
# 0  113957250  PORTA A PORTA TRANSPORTES LTDA        91870                7
# 1  113957259  PORTA A PORTA TRANSPORTES LTDA        91896                7
# 2  113960479  PORTA A PORTA TRANSPORTES LTDA        92697                7
#
#   Data Importação Pedido Data de Captura Data de Processamento  \
# 0         24/09/25 06:33  24/09/25 17:50        24/09/25 17:51
# ...

# %%
df_resultado_relatorio[['Entregador', 'Tipo','pedido_gemco']]
# Out:
#                            Entregador  \
# 0  MARCELO SILVA DE CARVALHO(GOIANIA)
# 1       TULIO CESAR DE OLIVEIRA SOUZA
# 2       TULIO CESAR DE OLIVEIRA SOUZA
# 3            ROGERIO ALMEIDA DE FARIA
# 4                         john Andrew
# 5       TULIO CESAR DE OLIVEIRA SOUZA
# 6              Anderson soares  pinto
#
#                                          Tipo  pedido_gemco
# 0                          Entrega Programada    1098196304
# 1                          Entrega Programada    1098193478
# 2               Pedido cancelado pelo cliente    1098271106
# 3  Endereço do Cliente Destino não Localizado    1098108180
# 4                1a Tentativa Cliente Ausente    1098231032
# 5                1a Tentativa Cliente Ausente    1098170808
# 6                     Troca de transportadora    1098059773
